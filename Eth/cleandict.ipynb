# %%
with open('rawdic.txt', 'r', encoding='utf-8') as file:
    dict1 = file.read()

# %%
dict1 = dict1.replace(' ', '')
dict1 = dict1.split('\n')

# %%
dict1
# Out:
# ['value',
#  '復興崗校區',
#  '輔仁聖博敏神學院',
#  '崇右影藝科技大學',
#  '健行科技大學',
#  '國立臺北科技大學',
#  '國立臺北教育大學',
#  '天主教臺灣總修院',
#  '法鼓文理學院',
#  '醫學院',
#  '國立陽明大學',
#  '聖德基督學院',
#  '南亞技術學院',
#  '銘傳大學',
#  '蘭陽技術學院',
#  '法鼓山僧伽大學',
#  '長庚大學',
#  '致理科技大學',
#  '龍華科技大學',
#  '陸軍化生放核訓練中心',
#  '國立臺灣戲曲學院',
#  '景文科技大學',
#  '臺北基督學院',
#  '國立臺北護理健康大學',
#  '馬偕醫護管理專科學校',
#  '國立臺灣大學',
#  '國立臺灣海洋大學',
#  '中華福音神學院',
#  '德霖科技大學',
#  '陸軍通信電子資訊訓練中心',
#  '國防醫學院',
#  '耕莘健康管理專科學校',
#  '國立中央大學',
#  '醒吾科技大學',
#  '華夏科技大學',
#  '佛光大學',
#  '台北海洋科技大學',
#  '經國管理暨健康學院',
#  '淡江大學',
#  '國立臺北藝術大學',
#  '中原大學',
#  '靈糧教牧宣教神學院',
#  '國立臺北大學',
#  '國立臺北商業大學',
#  '長庚科技大學',
#  '圓光佛學院',
#  '亞東技術學院',
#  '國立臺灣藝術大學',
#  '真理大學',
#  '東南科技大學',
#  '輔仁大學',
#  '元智大學',
#  '國立宜蘭大學',
#  '開南大學',
#  '臺北市立大學',
#  '聖約翰科技大學',
#  '國立臺灣科技大學',
#  '萬能科技大學',
#  '新生醫護管理專科學校',
#  '中央警察大學',
#  '臺灣警察專科學校',
#  '國立政治大學',
#  '陸軍專科學校',
#  '國立體育大學',
#  '國防大學',
#  '華梵大學',
#  '國立空中大學',
#  '黎明技術學院',
#  '陸軍後勤訓練中心',
#  '基督教拓荒宣教神學院',
#  '馬偕醫學院',
#  '明志科技大學',
#  '國立臺灣師範大學',
#  '高鐵桃園站',
# ...

# %%
with open('rawdic.txt', 'w', encoding='utf-8') as file:
    for i in range(len(dict1)):
        file.write(dict1[i])
        file.write('\n')

# %%
with open('p2.csv', 'r', encoding='utf-8') as file:
    p2 = file.read()

# %%
p2 = p2.replace('\"', '')
p2 = p2.split(',')

# %%
for i in range(len(p2)):
    p2[i] = p2[i].replace('[', '')
    p2[i] = p2[i].replace(']', '')
    p2[i] = p2[i].replace('\'', '')
    p2[i] = p2[i].replace(' ', '')

# %%
p2
# Out:
# ['55',
#  '貴子坑親山步道',
#  '56',
#  '二二八紀念館',
#  '57',
#  '二二八和平紀念公園',
#  '58',
#  '艋舺清水巖祖師廟',
#  '59',
#  '市長官邸藝文沙龍',
#  '60',
#  '和平青草園',
#  '61',
#  '李國鼎故居',
#  '62',
#  '台北市北門',
#  '63',
#  '台北市萬福國小',
#  '64',
#  '齊東街日式宿舍',
#  '65',
#  '幸町日式宿舍',
#  '67',
#  '臺大醫院',
#  '68',
#  '國立臺灣博物館',
#  '69',
#  '南門市場',
#  '70',
#  '石坊街',
#  '71',
#  '珍珠嶺人文廚房',
#  '72',
#  '新北聖誕城',
#  '74',
#  '',
#  '77',
#  '金瓜石勸濟堂',
#  '80',
#  '象鼻岩']

# %%
with open('p1.csv', 'r', encoding='utf-8') as file:
    p1 = file.read()

# %%
p1 = p1.split('\n')

# %%
for i in range(len(p1)):
    p1[i] = p1[i].replace('\\', '')
    p1[i] = p1[i].replace('\"', '')
    p1[i] = p1[i].replace('\'', '')
    p1[i] = p1[i].replace(' ', '')
    p1[i] = p1[i].replace('\ufeff', '')
    p1[i] = p1[i].replace('[', '')
    p1[i] = p1[i].replace(']', '')
    p1[i] = p1[i].split(',')

# %%
dictp1 = []
for i in range(len(p1)):
    for j in range(1, len(p1[i])):
        dictp1.append(p1[i][j])

# %%
dictp1 = list(set(dictp1))

# %%
dictp1
# Out:
# ['',
#  '羅東中山公園',
#  '幾米廣場',
#  '甲鳥園',
#  '宜蘭傳統藝術中心',
#  '童玩節',
#  '羅東運動公園',
#  '情人橋',
#  '新北市歡樂耶誕城',
#  '十份老街',
#  '基隆廟口夜市',
#  '飛天列車',
#  '本事農莊',
#  '清水地熱公園',
#  '永春崗步道',
#  '140高地公園',
#  '蘇澳冷泉',
#  '平溪老街',
#  '頭城運動公園',
#  '文心蘭金黃隧道',
#  '圓爵瀑布',
#  '巨石公園步道',
#  '平溪車站',
#  '丟丟噹森林',
#  '美堤河濱公園',
#  '白石湖吊橋',
#  '邱比準',
#  '北星寶宮步道',
#  '松山菸廠',
#  '一米特創藝美食館',
#  '銀河洞越嶺步道',
#  '樂火戰士',
#  '綺麗親子夢想館',
#  '大溝溪親水公園',
#  '老地方觀景平台',
#  '九份老街',
#  '冬山稻間美徑',
#  '基隆廟口',
#  '大進國小',
#  '十份瀑布',
#  '鹿皮溪',
#  '金車生技水產養殖研發中心',
#  '新店',
#  '幸福時光親子餐廳',
#  '宜農牧場',
#  '樂去。玩的瘋',
#  '武荖坑風景區',
#  '冬山火車站',
#  '金岳瀑布',
#  '101的景觀台',
#  '一線天步道',
#  '地熱谷',
#  '武淵水火同源',
#  '九份金礦博物館',
#  '大理國小',
#  '坪林',
#  '馬德里休閒驛棧',
#  '溫泉博物館',
#  '斑比山丘',
#  '奇麗灣珍奶文化館',
#  '瘋狂夢想藝術園區',
#  '宜蘭縣壯圍親子館',
#  '蘭陽溪口親子餐廳',
#  '圓爵寺步道',
#  '鯉魚山親山步道',
#  '南澳建華冰店',
#  '菁桐老街',
#  '華山1914文化園區',
#  '北投圖書館',
#  '宜蘭火車站',
#  '臺北101大樓']

# %%
dictp2 = []
for i in range(len(p2)):
    if i%2 != 0:
        dictp2.append(p2[i])
    else:
        continue

# %%
dictp2 = list(set(dictp2))

# %%
dictp2
# Out:
# ['二二八紀念館',
#  '國立臺灣博物館',
#  '',
#  '象鼻岩',
#  '齊東街日式宿舍',
#  '貴子坑親山步道',
#  '臺大醫院',
#  '台北市北門',
#  '市長官邸藝文沙龍',
#  '李國鼎故居',
#  '新北聖誕城',
#  '艋舺清水巖祖師廟',
#  '南門市場',
#  '幸町日式宿舍',
#  '珍珠嶺人文廚房',
#  '金瓜石勸濟堂',
#  '台北市萬福國小',
#  '二二八和平紀念公園',
#  '石坊街',
#  '和平青草園']

# %%
with open('p3.csv', 'r', encoding='utf-8') as file:
    p3 = file.read()

# %%
p3 = p3.split('\n')

# %%
for i in range(len(p3)):
    p3[i] = p3[i].replace('\\', '')
    p3[i] = p3[i].replace('\"', '')
    p3[i] = p3[i].replace('\'', '')
    p3[i] = p3[i].replace(' ', '')
    p3[i] = p3[i].replace('\ufeff', '')
    p3[i] = p3[i].replace('[', '')
    p3[i] = p3[i].replace(']', '')
    p3[i] = p3[i].split(',')

# %%
p3
# Out:
# [['89', '金字碑古道', '大粗坑古道', '侯硐貓村', '不厭亭', ''],
#  ['92', '黃金博物館', '陰陽海', '濂洞國小', '黃金瀑布', '十三層遺址', '不厭亭'],
#  ['97', '象鼻岩', '駱駝峰'],
#  ['98', '五寮尖'],
#  ['99', '金山驛境'],
#  ['100', '龍潭湖', '野柳'],
#  ['103', '華中河濱公園', '馬場町', '中正河濱公園', '雁鴨公園'],
#  ['107', '古亭河濱公園'],
#  ['108', '福德坑環保復育園區'],
#  ['109', '拳山古道'],
#  ['110', '寶藏巖'],
#  ['111', '寶藏巖'],
#  ['112', '義芳居古厝'],
#  ['113', ''],
#  ['114', '木棉花道'],
#  ['116', '古亭河濱公園'],
#  ['117', '山水綠生態公園', '新生公園'],
#  ['118', '南機場夜市'],
#  ['119', '通化夜市', '臨江街觀光夜市'],
#  ['120', '鹿窟菜廟', '光明禪寺'],
#  ['123', '大安森林公園'],
#  ['126', '圓山動物園', '臺北兒童育樂中心'],
#  ['129', '大安森林公園', '二二八和平公園'],
#  ['130', '樟湖步道', '鵝角格山', '樟樹步道', '銀河洞'],
#  ['131', '三玄宮山', '鵝角格山', '銀河洞', '指南宮'],
#  ['132', '指南宮', '終南亭'],
#  ['133', '慈聖宮', '老泉街'],
#  ['134', '老泉街', '慈音休閒', '樟湖步道', '貓空纜車'],
#  ['135', '樟湖步道', '待老坑山', '鵝角格山', '貓空越嶺古道'],
#  ['136', '貓空', '樟湖步道', '張迺妙', '三玄宮'],
#  ['137', '貓空纜車'],
#  ['138', '貓空纜車'],
#  ['140', '貓空', '明德宮'],
#  ['141', '茶香環狀步道', '壼穴', '小天空步道'],
# ...

# %%
dictp3 = []
for i in range(len(p3)):
    for j in range(1, len(p3[i])):
        dictp3.append(p3[i][j])

# %%
dictp3 = list(set(dictp3))

# %%
dictp3
# Out:
# ['',
#  '老泉街',
#  '象鼻岩',
#  '五寮尖',
#  '大屯自然公園',
#  '大安森林公園',
#  '張迺妙',
#  '濂洞國小',
#  '黃金瀑布',
#  '金字碑古道',
#  '天山步道',
#  '銀河洞',
#  '侯硐貓村',
#  '二子坪遊憩區',
#  '貓空纜車',
#  '三玄宮山',
#  '臨江街觀光夜市',
#  '明德宮',
#  '拳山古道',
#  '茶香環狀步道',
#  '通化夜市',
#  '十三層遺址',
#  '黃金博物館',
#  '馬場町',
#  '五分碑步道',
#  '光明禪寺',
#  '慈聖宮',
#  '大粗坑古道',
#  '樟樹步道',
#  '野柳',
#  '華中河濱公園',
#  '寶藏巖',
#  '駱駝峰',
#  '古亭河濱公園',
#  '義芳居古厝',
#  '慈音休閒',
#  '東湖櫻花林',
#  '臺北兒童育樂中心',
#  '龍潭湖',
#  '中正河濱公園',
#  '圓山動物園',
#  '鵝角格山',
#  '貓空',
#  '三玄宮',
#  '小天空步道',
#  '壼穴',
#  '指南宮',
#  '內溝步道',
#  '南機場夜市',
#  '樟湖步道',
#  '終南亭',
#  '二二八和平公園',
#  '樂康步道',
#  '福德坑環保復育園區',
#  '陰陽海',
#  '潮境公園',
#  '木棉花道',
#  '金山驛境',
#  '山水綠生態公園',
#  '新生公園',
#  '貓空越嶺古道',
#  '老泉里',
#  '不厭亭',
#  '雁鴨公園',
#  '待老坑山',
#  '八斗子',
#  '鹿窟菜廟']

# %%
dictall = []
dictall = dict1 + dictp2 + dictp3 + dictp1

# %%
dictall = list(set(dictall))

# %%
len(dictall)
# Out:
# 2436

# %%
with open('self_bigdict_test.txt', 'r', encoding='utf-8') as file:
    self = file.read()

# %%
self = self.replace('\ufeff', '')
self = self.split('\n')

# %%
self
# Out:
# ['學海書院',
#  '文海書院',
#  '小叮噹科學主題樂園',
#  '六福村主題遊樂園',
#  '清水巖祖師廟',
#  '孔廟',
#  '大稻埕',
#  '冬山河',
#  '蘆竹大夫第',
#  '義美觀光工廠',
#  '七家灣',
#  '平鎮運動公園',
#  '五酒桶山',
#  '星海之戀',
#  '大粗坑大德宮',
#  '金字碑',
#  '靈巖寺',
#  '滴水觀音',
#  '大屯自然公園',
#  '天山步道',
#  '二子坪遊憩區',
#  '指南宮',
#  '林家花園',
#  '黃金博物館',
#  '濂洞國小',
#  '五寮尖山',
#  '金山驛境',
#  '龍潭湖公園',
#  '中正河濱公園',
#  '雁鴨公園',
#  '古亭河濱公園',
#  '福德坑環保復育園區',
#  '拳山古道',
#  '台大羅斯福路木棉花道',
#  '新生公園',
#  '南機場夜市',
#  '通化夜市',
#  '臺北市兒童新樂園',
#  '光明禪寺',
#  '樟湖步道',
#  '鵝角格山',
#  '慈聖宮',
#  '慈音休閒',
#  '貓空三玄宮',
#  '八斗子',
#  '五分碑步道',
#  '樂康步道',
#  '內溝步道',
#  '東湖櫻花林']

# %%
dictall = dictall + self
dictall = list(set(dictall))
dictall = list(filter(None, dictall))

# %% [markdown]
# remove blank in list https://stackoverflow.com/questions/3845423/remove-empty-strings-from-a-list-of-strings

# %%
with open('bigdict_v4-2.csv', 'w', encoding='utf-8') as  file:
    for i in range(len(dictall)):
        file.write(dictall[i])
        file.write('\n')

# %%
with open('rawdic.txt', 'w', encoding='utf-8') as  file:
    for i in range(len(dictall)):
        file.write(dictall[i])
        file.write('\n')
