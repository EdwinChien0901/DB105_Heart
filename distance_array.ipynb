# %%
from math import radians, cos, sin, asin, sqrt

import numpy as np

# def haversine(df.loc[0,'longitude'], df.loc[0,'latitude'],df.loc[i,'longitude'], df.loc[i,'latitude'])
 
def haversine(lon1, lat1, lon2, lat2): # 经度1，纬度1，经度2，纬度2 （十进制度数）
    """
    Calculate the great circle distance between two points 
    on the earth (specified in decimal degrees)
    """
    # 将十进制度数转化为弧度
    lon1, lat1, lon2, lat2 = map(radians, [lon1, lat1, lon2, lat2])
    

#     vector1 = np.array([lon1, lat1]).reshape(2, 1)

#     vector2 = np.array([lon2, lat2]).reshape(2, 1)

    # haversine公式
    
#     dlon = vector2[0,0]-vector1[0,0]
        
#     dlat = vector2[1,0]-vector1[1,0]
        
    dlon = lon2 - lon1 
        
    dlat = lat2 - lat1 




    a = sin(dlat/2)**2 + cos(lat1) * cos(lat2) * sin(dlon/2)**2
    c = 2 * asin(sqrt(a)) 
    r = 6371 # 地球平均半径，单位为公里
    
    b = 0
    
    return round(c * r,3)

# %%
import pandas as pd

csv_file = "C:/Users/Big data/Desktop/report/north_place_google_api_area_v1.csv"
csv_data = pd.read_csv(csv_file, low_memory = False)#防止弹出警告
df = pd.DataFrame(csv_data)

# %%
df
# Out:
#                                                     url place_name area  \
# 0     https://tour.ntpc.gov.tw/zh-tw/Attraction/Deta...       九份老街  新北市
# 1     https://tour.ntpc.gov.tw/zh-tw/Attraction/Deta...     野柳地質公園  新北市
# 2     https://tour.ntpc.gov.tw/zh-tw/Attraction/Deta...    三貂嶺瀑布步道  新北市
# 3     https://tour.ntpc.gov.tw/zh-tw/Attraction/Deta...        新月橋  新北市
# 4     https://tour.ntpc.gov.tw/zh-tw/Attraction/Deta...        不厭亭  新北市
# ...                                                 ...        ...  ...
# 1918  https://tour.klcg.gov.tw/zh/attractions/temple...        奠濟宮  基隆市
# 1919  https://tour.klcg.gov.tw/zh/attractions/temple...      暖暖安德宮  基隆市
# 1920  https://tour.klcg.gov.tw/zh/attractions/temple...   暖暖雙生土地公廟  基隆市
# 1921  https://tour.klcg.gov.tw/zh/attractions/temple...     獅球嶺平安宮  基隆市
# 1922  https://tour.klcg.gov.tw/zh/attractions/temple...        慶安宮  基隆市
#
#                       address   longitude   latitude
# ...

# %%
df.loc[0,'longitude']
# Out:
# 121.84518270000001

# %%
df.loc[0,'latitude']
# Out:
# 25.109869500000002

# %%
df.loc[1,'longitude']
# Out:
# 121.6904658

# %%
df.loc[1,'latitude']
# Out:
# 25.206397199999998

# %%
place_list = df['place_name'].tolist()#從dataframe提取景點list供後續查長度

# %% [markdown]
# 產生row，每個row代表與其他景點的距離

# %%
for n in range(1923):
    
    place_list[n] = []
    
#     print(place_list[a])

# for n in range(1923):
    
#     if n < i:

    lon1=df.loc[n,'longitude']

    lat1=df.loc[n,'latitude']

    for i in range(1923):

        lon2=df.loc[i,'longitude']

        lat2=df.loc[i,'latitude']

        place_list[n].append(haversine(lon1, lat1, lon2, lat2))       

    print(np.array(place_list[n]))
# Out:
# [ 0.    18.913  5.43  ... 11.316 11.255 10.755]
# [18.913  0.    20.545 ... 13.062 10.297  9.916]
# [ 5.43  20.545  0.    ...  9.538 10.928 10.903]
# [41.89  33.711 38.455 ... 30.781 32.01  32.919]
# [ 4.866 22.342  2.719 ... 12.097 13.193 13.036]
# [ 0.136 19.048  5.41  ... 11.417 11.376 10.881]
# [18.441  1.112 19.823 ... 12.087  9.388  9.073]
# [40.528 40.861 35.562 ... 31.919 34.436 35.426]
# [41.37  25.509 40.291 ... 30.776 30.128 30.626]
# [51.717 44.27  47.892 ... 40.839 42.281 43.215]
# [26.144 24.005 22.109 ... 15.918 18.059 19.055]
# [ 1.262 20.007  5.999 ... 12.553 12.515 12.006]
# [41.778 25.826 40.724 ... 31.206 30.538 31.03 ]
# [ 2.071 19.477  7.385 ... 13.074 12.689 12.08 ]
# [ 3.108 19.143  2.435 ...  9.472 10.188  9.948]
# [40.135 31.623 36.836 ... 28.964 30.104 31.002]
# [51.77  44.284 47.953 ... 40.886 42.321 43.254]
# [48.084 39.702 44.541 ... 37.013 38.26  39.169]
# [41.35  25.558 40.242 ... 30.732 30.104 30.608]
# [40.717 30.614 37.801 ... 29.422 30.235 31.079]
# ...

# %% [markdown]
# 用dataframe將row合併

# %%
import pandas as pd

res = pd.DataFrame()

for d in range(1923):
    
    df1 = pd.DataFrame(np.array(place_list[d]).reshape(1,len(place_list[d])),columns=[list(range(1923))])
    
    res=res.append(df1,ignore_index='True')

# %%
res
# Out:
#         0       1       2       3       4       5       6       7       8     \
# 0      0.000  18.913   5.430  41.890   4.866   0.136  18.441  40.528  41.370
# 1     18.913   0.000  20.545  33.711  22.342  19.048   1.112  40.861  25.509
# 2      5.430  20.545   0.000  38.455   2.719   5.410  19.823  35.562  40.291
# 3     41.890  33.711  38.455   0.000  41.139  41.975  32.847  18.288  19.440
# 4      4.866  22.342   2.719  41.139   0.000   4.781  21.702  37.745  42.873
# ...      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 1918  10.455  10.192  10.593  33.096  12.720  10.580   9.359  35.443  30.921
# 1919  10.768  12.569   9.382  31.479  11.862  10.874  11.626  32.772  31.045
# 1920  11.316  13.062   9.538  30.781  12.097  11.417  12.087  31.919  30.776
# 1921  11.255  10.297  10.928  32.010  13.193  11.376   9.388  34.436  30.128
# 1922  10.755   9.916  10.903  32.919  13.036  10.881   9.073  35.426  30.626
#
# ...
